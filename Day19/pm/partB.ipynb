# %%
import numpy as np
import matplotlib.pyplot as plt

normal = np.random.normal(0,1,1000)
uniform = np.random.uniform(0,1,1000)

plt.hist(normal, bins=30, alpha=0.5)
plt.hist(uniform, bins=30, alpha=0.5)
plt.show()
