# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode

data = np.random.normal(50, 10, 1000)

print(np.mean(data), np.var(data), np.std(data))

plt.hist(data, bins=30)
plt.show()
# Out:
# 49.54343651656948 107.56692220761589 10.371447449976106

# %%
def bernoulli_pmf(p):
    return {0: 1-p, 1: p}

pmf = bernoulli_pmf(0.6)
print(sum(pmf.values()))
# Out:
# 1.0

# %%
def normal_pdf(x, mu, sigma):
    return (1/(sigma*np.sqrt(2*np.pi))) * np.exp(-((x-mu)**2)/(2*sigma**2))

# %%
print("mean:", np.mean(data))
print("median:", np.median(data))
print("mode:", mode(data))
# Out:
# mean: 49.54343651656948
# median: 49.62215543372336
# mode: ModeResult(mode=np.float64(17.438211331939364), count=np.int64(1))

# %%
coin = np.random.choice([0,1], 1000)
print("P(heads):", np.mean(coin))
# Out:
# P(heads): 0.508
